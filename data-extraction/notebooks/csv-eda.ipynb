# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/metadata/gutenberg_metadata.csv')
df
# Out:
#                                               Title  \
# 0           The Extermination of the American Bison
# 1                              Deadfalls and Snares
# 2                       Artistic Anatomy of Animals
# 3                                Birds, Illustrated
# 4      On Snake-Poison: Its Action and Its Antidote
# ...                                             ...
# 15326                                    Psichopath
# 15327                                  Poisoned Air
# 15328                         Cry from a Far Planet
# 15329                               Spies Die Hard!
# 15330                                  The Doomsman
#
#                                          Author  \
# 0                           William T. Hornaday
# 1                                 A. R. Harding
# 2                                 Édouard Cuyer
# 3      Color Photography, Vol. 1, No. 1 Various
# 4                                    A. Mueller
# ...

# %%
df['Bookshelf'].unique()
# Out:
# array(['Animal', 'Animals-Domestic', 'Animals-Wild',
#        'Animals-Wild-Trapping', 'Animals-Wild-Birds',
#        'Animals-Wild-Insects', 'Animals-Wild-Mammals',
#        'Animals-Wild-Reptiles', 'Canada', "Children's", 'School',
#        "Child's", 'Harvard', 'Classical', '6', 'Travel', 'Christmas',
#        'Italy', 'United', 'Norway', 'Bulgaria', 'Argentina', 'South',
#        "Women's", 'New', 'France', 'Greece', 'Germany', 'Australia',
#        'Egypt', 'India', 'Africa', 'Crime', 'Mystery', 'Detective',
#        'Language', 'Education', 'General', 'Romantic', 'FR', 'Western',
#        'Erotic', 'Fantasy', 'Humor', 'Adventure', 'Science', 'Precursors',
#        'Horror', 'Historical', 'Gothic', 'The', 'Architecture', 'Art',
#        'Reference', 'IT', 'Czech', 'Maps', 'Camping', 'CIA',
#        'Anthropology', 'Folklore', 'Current', 'Natural', 'Archaeology',
#        'Biographies', 'German', 'Canon', 'Noteworthy', 'British', 'Music',
# ...

# %%
df[
    (df['Bookshelf'] == "Children's") | \
    (df['Bookshelf'] == "Child's") | \
    (df['Bookshelf'] == 'School') | \
    (df['Bookshelf'] == 'Education') |\
    (df['Bookshelf'] == 'Folklore') |\
    (df['Bookshelf'] == 'Fantasy') |\
    (df['Bookshelf'] == 'Adventure') |\
    (df['Bookshelf'] == 'Science') |\
    (df['Bookshelf'] == 'Detective')
]
# Out:
#                                                   Title  \
# 225   Twas the Night before Christmas: A Visit from ...
# 226                            The Tale of Peter Rabbit
# 227     Struwwelpeter: Merry Stories and Funny Pictures
# 228   Children's Hour with Red Riding Hood and Other...
# 229                                  The Little Red Hen
# ...                                                 ...
# 1538                                 Japanische Märchen
# 1539                         More Russian Picture Tales
# 1540                              A Chinese Wonder Book
# 1541  Myths and Legends of California and the Old So...
# 1542                     Myths and Legends of the Sioux
#
#                            Author                                   Link  \
# 225          Clement Clarke Moore  http://www.gutenberg.org/ebooks/17135
# 226                Beatrix Potter  http://www.gutenberg.org/ebooks/14838
# ...

# %%
df = df[
    (df['Bookshelf'] == "Children's") | \
    (df['Bookshelf'] == "Child's") | \
    (df['Bookshelf'] == 'School') | \
    (df['Bookshelf'] == 'Education') |\
    (df['Bookshelf'] == 'Folklore') |\
    (df['Bookshelf'] == 'Fantasy') |\
    (df['Bookshelf'] == 'Adventure') |\
    (df['Bookshelf'] == 'Science') |\
    (df['Bookshelf'] == 'Detective')
]

df.to_csv('../../data/metadata/subset.csv')
